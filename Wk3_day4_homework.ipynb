# %%
# # # # LinkedList for GitHub: i want to create nodes called Commits (a class), linked to another class called Repo. 
# # # I want to create and link more commits as they are created and be able to move them in place. Pull_request will
# # create a new node(Commits) and place at the front, Checkout will insert, add will append. i copied the code from class and 
# adjusted to my gitworld example but it doesnt work!
class Commits():
    def __init__(self,value):
        self.value = value
        self.next = None

class Repo():
    def __init__(self):
        self.head = None
               
    def pull_request(self, new_value):
        new_commit = Commits(new_value)
        new.commit.next = self.head
        self.head = new_commit
        
    def checkout(self, prev_commit, new_value):
        if prev_commit is None:
            print("No previous changes")
            return
        new_commit = Commits(new_value)
        new_commit.next = prev_commit.next
        prev_commit.next = new_commit
        
    def add(self, new_value):
        new_commit = Commits(new_value)
        if self.head is None:
            self.head = new_commit
        last = self.head
        while(last.next):
            last = last.next
        last.next = new_commit
    def traverse(self):
        temp = self.head
        while(temp):
            print(temp.value)
        temp = temp.next
            
            
gitcommits = Commits()            
commita = gitcommits(a)
commitb = gitcommits(b)
commita.next = commitb
gitcommits.pull_request(commita)
gitcommits.pull_request(commitb)
gitcommits.add(commita)
gitcommits.add(commitb)
gitcommits.checkout(commitb, commita)
gitcommits.traverse()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-59fa98aa23c7> in <module>
#      37
#      38
# ---> 39 gitcommits = Commits(a,b)
#      40 commita = gitcommits(a)
#      41 commitb = gitcommits(b)
#
# NameError: name 'a' is not defined

# %%
# # #binary search tree of a tree called "Moods" containing leaves of how many times a mood was used, 
# so anger = 100, m_anger = Moods(100)
# # m_saddness.insert(40)
# # m_worry.insert(50)
# # m_fear.insert(88)
# # m_anxiety.insert(76)


class Moods():
    def __init__(self,value):
        self.value = value 
        self.left = None
        self.right = None
        
    def insert(self,value):
        if value < self.value:
            if self.left is None:
                self.left = Moods(value)
            else:
                self.left.insert(value)
        else:
            if self.right is None:
                self.right = Moods(value)
            else:
                self.right.insert(value)
        return self
    
    def contains(self,value):
        if value < self.value: 
            if self.left is None:
                return False
            else:
                return self.left.contains(value)
        elif value > self.value:
            if self.right is None:
                return False
            else:
                return self.right.contains(value)
        else:
            return True
        
    def getMinValue(self):
        if self.left is None:
            return self.value
        else:
            return self.left.getMinValue()
    
    def getMaxValue(self):
        if self.right is None:
            return self.value
        else:
            return self.right.getMaxValue()
        
    def remove(self,value,parent=None):
        if value < self.value:
            if self.left is not None:
                self.left.remove(value,self)
        elif value > self.value:
            if self.right is not None:
                self.right.remove(value,self)
        else:
            if self.left is not None and self.right is not None:
                self.value = self.right.getMinValue()
                self.right.remove(self.value,self)
            elif parent is None:
                if self.left is not None:
                    self.value = self.left.value
                    self.right = self.left.right
                    self.left = self.left.left
                elif self.right is not None:
                    self.value = self.right.value
                    self.left = self.right.left
                    self.right = self.right.right
                else:
                    self.value = None
            elif parent.left == self:
                parent.left = self.left if self.left is not None else self.right
            elif parent.right == self:
                parent.right = self.left if self.left is not None else self.right
        return self
    
m_anger = Moods(100)
m_saddness.insert(40)
m_worry.insert(50)
m_fear.insert(88)
m_anxiety.insert(76)


print(m_anger.getMaxValue())
print(m_saddness.contains(76))
